# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

df = pd.read_csv("ROB.csv")

X = df.iloc[:, 6:].values
y = df.iloc[:, :6].values

scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

model = Sequential([
    LSTM(64, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    LSTM(32, activation='relu', return_sequences=False),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1])
])

model.compile(optimizer='adam', loss='mse')

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

test_loss = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
# Out:
# C:\Users\arjun\anacondaNEW\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.1680 - val_loss: 0.0821
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0797 - val_loss: 0.0791
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0773 - val_loss: 0.0786
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0772 - val_loss: 0.0778
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0763 - val_loss: 0.0778
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0755 - val_loss: 0.0776
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0756 - val_loss: 0.0773
# Epoch 8/100
# ...

# %%
import numpy as np

new_coordinates = np.array([[0.142, 0.1, 0.225]])

new_coordinates_scaled = scaler_X.transform(new_coordinates)
new_coordinates_scaled = new_coordinates_scaled.reshape((new_coordinates_scaled.shape[0], 1, new_coordinates_scaled.shape[1]))

predicted_joint_angles_scaled = model.predict(new_coordinates_scaled)
predicted_joint_angles = scaler_y.inverse_transform(predicted_joint_angles_scaled)

print("Predicted Joint Angles:", predicted_joint_angles)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Predicted Joint Angles: [[-28.495626  -19.299288   91.593056    1.1271187  -2.1042418 178.35075  ]]
