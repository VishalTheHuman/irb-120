# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

df = pd.read_csv("ROB.csv")

X = df.iloc[:, :6].values
y = df.iloc[:, 6:].values

scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

model = Sequential([
    LSTM(64, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    LSTM(32, activation='relu', return_sequences=False),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1])
])

model.compile(optimizer='adam', loss='mse')

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

test_loss = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)

predictions = model.predict(X_test)

predictions_inv = scaler_y.inverse_transform(predictions)
# Out:
# C:\Users\arjun\anacondaNEW\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.1077 - val_loss: 0.0282
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0280 - val_loss: 0.0268
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0260 - val_loss: 0.0246
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0229 - val_loss: 0.0203
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0170
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - val_loss: 0.0130
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0120 - val_loss: 0.0101
# Epoch 8/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 9/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 10/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 11/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 12/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 13/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 14/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 15/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 16/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 17/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 18/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 19/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 20/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 21/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 22/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 23/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 24/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 25/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 26/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 27/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 28/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 29/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 30/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 31/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 32/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 33/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 34/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 35/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 36/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 37/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 38/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 39/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 40/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 41/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 42/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 43/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 44/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 45/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 46/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 47/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 48/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 49/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 50/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 51/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 52/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 53/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 54/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 55/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 56/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 57/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 58/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 59/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 60/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 61/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 62/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.7803e-04 - val_loss: 0.0011
# Epoch 63/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 64/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.8225e-04 - val_loss: 9.9685e-04
# Epoch 65/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2181e-04 - val_loss: 0.0012
# Epoch 66/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 67/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4367e-04 - val_loss: 0.0010
# Epoch 68/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.9691e-04 - val_loss: 0.0011
# Epoch 69/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2561e-04 - val_loss: 0.0011
# Epoch 70/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.0748e-04 - val_loss: 9.8775e-04
# Epoch 71/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.8483e-04 - val_loss: 0.0010
# Epoch 72/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.0147e-04 - val_loss: 9.1693e-04
# Epoch 73/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.1818e-04 - val_loss: 9.6858e-04
# Epoch 74/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.2569e-04 - val_loss: 0.0011
# Epoch 75/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.7577e-04 - val_loss: 9.8016e-04
# Epoch 76/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.6463e-04 - val_loss: 8.9152e-04
# Epoch 77/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9985e-04 - val_loss: 9.9629e-04
# Epoch 78/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.0642e-04 - val_loss: 9.7071e-04
# Epoch 79/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.1160e-04 - val_loss: 8.8861e-04
# Epoch 80/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.7569e-04 - val_loss: 0.0010
# Epoch 81/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.1437e-04 - val_loss: 8.3210e-04
# Epoch 82/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9854e-04 - val_loss: 8.9059e-04
# Epoch 83/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8746e-04 - val_loss: 9.1605e-04
# Epoch 84/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6559e-04 - val_loss: 0.0011
# Epoch 85/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9106e-04 - val_loss: 8.9115e-04
# Epoch 86/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.4771e-04 - val_loss: 8.3100e-04
# Epoch 87/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3082e-04 - val_loss: 8.4093e-04
# Epoch 88/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4470e-04 - val_loss: 8.9569e-04
# Epoch 89/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.6277e-04 - val_loss: 8.1652e-04
# Epoch 90/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0747e-04 - val_loss: 8.1752e-04
# Epoch 91/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3755e-04 - val_loss: 0.0010
# Epoch 92/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0306e-04 - val_loss: 8.6806e-04
# Epoch 93/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0669e-04 - val_loss: 7.8999e-04
# Epoch 94/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8584e-04 - val_loss: 7.7632e-04
# Epoch 95/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.0526e-04 - val_loss: 7.6630e-04
# Epoch 96/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.3085e-04 - val_loss: 7.9438e-04
# Epoch 97/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.9076e-04 - val_loss: 8.8371e-04
# Epoch 98/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.8119e-04 - val_loss: 8.5331e-04
# Epoch 99/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.7814e-04 - val_loss: 7.4340e-04
# Epoch 100/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.7522e-04 - val_loss: 6.9595e-04
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7476e-04
# Test Loss: 0.0006764013087376952
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
